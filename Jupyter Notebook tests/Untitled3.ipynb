# %%
import numpy as np
import geomdl
import scipy.interpolate as interp
from scipy.interpolate import BSpline, SmoothBivariateSpline, LSQBivariateSpline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools

# %%
def cartesian_product(*arrays):
    la = len(arrays)
    dtype = np.result_type(*arrays)
    arr = np.empty([len(a) for a in arrays] + [la], dtype=dtype)
    for i, a in enumerate(np.ix_(*arrays)):
        arr[...,i] = a
    return arr.reshape(-1, la)

# %%
x = np.linspace(0,np.pi,101)
y = np.linspace(0,np.pi,101)
xy= cartesian_product(x,y)
xx = xy[:, 0]
yy = xy[:, 1]
zz = np.sin(xx*yy)

# %%
zz
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.24491726,
#        -0.33926025, -0.43030122])

# %%
s = interp.make_lsq_spline(xx,yy,t-100, k=3, )
s2 = SmoothBivariateSpline(xx,yy,zz,kx=3,ky=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-278-c6c57ac2d5b2> in <module>
# ----> 1 s = interp.make_lsq_spline(xx,yy,t-100, k=3, )
#       2 s2 = SmoothBivariateSpline(xx,yy,zz,kx=3,ky=3)
#
# d:\program files\python37\lib\site-packages\scipy\interpolate\_bsplines.py in make_lsq_spline(x, y, t, k, w, axis, check_finite)
#     984
#     985     if x.ndim != 1 or np.any(x[1:] - x[:-1] <= 0):
# --> 986         raise ValueError("Expect x to be a 1-D sorted array_like.")
#     987     if x.shape[0] < k+1:
#     988         raise ValueError("Need more x points.")
#
# ValueError: Expect x to be a 1-D sorted array_like.

# %%
tck[2]
# Out:
# array([ -0.02901255,   0.3234291 ,  -1.28030678,   1.41364178,
#          0.3234291 ,  -1.36266736,   9.88888128,  -2.13935516,
#         -1.28030678,   9.88888128, -13.77381501,   0.82521132,
#          1.41364178,  -2.13935516,   0.82521132,   1.74149686])

# %%
tck[0]
# Out:
# array([0.        , 0.        , 0.        , 0.        , 3.14159265,
#        3.14159265, 3.14159265, 3.14159265])

# %%
#Initialize 3d figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
Axes3D.plot(ax, xx, yy, zz, 'r*')
Axes3D.plot(ax, xx, yy, zs, 'b-')

# %%
zs
# Out:
# array([[-6.66277214e-17,  8.90671617e-05,  3.53642588e-04, ...,
#          2.43799800e-01,  2.42366190e-01,  2.40722059e-01],
#        [ 8.90671617e-05,  9.86960440e-04,  2.06159360e-03, ...,
#          2.91862311e-01,  2.90197432e-01,  2.88299329e-01],
#        [ 3.53642588e-04,  2.06159360e-03,  3.94784176e-03, ...,
#          3.41768754e-01,  3.39905750e-01,  3.37787145e-01],
#        ...,
#        [ 2.43799800e-01,  2.91862311e-01,  3.41768754e-01, ...,
#          9.47876807e+00,  9.57505567e+00,  9.67045565e+00],
#        [ 2.42366190e-01,  2.90197432e-01,  3.39905750e-01, ...,
#          9.57505567e+00,  9.67319927e+00,  9.77046447e+00],
#        [ 2.40722059e-01,  2.88299329e-01,  3.37787145e-01, ...,
#          9.67045565e+00,  9.77046447e+00,  9.86960440e+00]])
