# %%
from gekko import brain
import struct
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle

# %%
# Get data from binary file

# %%
# Get field nodes
file = open("D:/Documents/RLUtilities/assets/soccar/soccar_navigation_nodes.bin",
            "rb")
xd = []
yd = []
zd = []
byte = file.read(4)
while(byte):
    xd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)
    yd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)
    zd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)

# %%
#Get field node normals
file = open("D:/Documents/RLUtilities/assets/soccar/soccar_navigation_normals.bin",
            "rb")
xnd = []
ynd = []
znd = []
byte = file.read(4)
while(byte):
    xnd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)
    ynd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)
    znd.append(list(struct.unpack('f', byte)))
    byte = file.read(4)

# %%
len(xd), len(yd), len(zd), len(xnd), len(ynd), len(znd)
# Out:
# (12115, 12115, 12115, 12115, 12115, 12115)

# %%
# setup input and output matricies
# dim(axis) 0 is input layer size (3), and dim(axis) 1 is #datasets
# Transpose since vector comes in with axis 0 the data sets
x = np.asarray(xd).T
y = np.asarray(yd).T
z = np.asarray(zd).T
xn = np.asarray(xnd).T
yn = np.asarray(ynd).T
zn = np.asarray(znd).T
x.shape, y.shape, z.shape, xn.shape, yn.shape, zn.shape
# Out:
# ((1, 12115), (1, 12115), (1, 12115), (1, 12115), (1, 12115), (1, 12115))

# %%
input = np.concatenate((x,y,z), axis = 0)
output = np.concatenate((xn, yn, zn), axis = 0)
input.shape, output.shape
# Out:
# ((3, 12115), (3, 12115))

# %%
# Remove x y z < 0
# i = input[:, np.all(input > 0, axis=0)]
# o = output[:, np.all(input >0, axis=0)]
i = input
o = output
np.all(i>0), i.shape, o.shape
# Out:
# (False, (3, 12115), (3, 12115))

# %%
np.sum(np.linalg.norm(o, axis=0)-1)
# Out:
# -2.1711470729046667e-06

# %%
# Shuffle array so that the first 1000 give hopefully good cover on the manifold
def shuffle(node, norm):
    n = len(node[0])
    grid = np.zeros(n, dtype=np.int32)
    for i in range(0,len(grid)): grid[i] = i
    np.random.shuffle(grid)
    print('grid: ', grid)
    return node[:,grid], norm[:,grid]
i,o = shuffle(i, o)
print('i: ', i, ' | o: ', o)
# Out:
# grid:  [ 4271 10638 11362 ...  1158 11348 10012]
# i:  [[-1280.         -2815.94873047  3455.97802734 ... -2048.
#    3705.98828125 -4067.75366211]
#  [ 1536.          4351.96875      896.         ... -2304.
#     384.          1792.        ]
#  [   17.          2031.          2031.         ...    17.
#    2019.62207031  1658.3614502 ]]  | o:  [[ 0.00000000e+00  4.12410162e-02 -3.95232923e-02 ...  0.00000000e+00
#   -2.02443764e-01  9.86843169e-01]
#  [ 0.00000000e+00 -4.12396975e-02  1.03025748e-07 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 1.00000000e+00 -9.98297811e-01 -9.99218643e-01 ...  1.00000000e+00
#   -9.79293883e-01 -1.61680207e-01]]

# %%
start = 0
stop = 500
ip1=i[:,start:stop]
op1 = o[:,start:stop]
ip1.shape, op1.shape
# Out:
# ((3, 500), (3, 500))

# %%
#Initialize 3d figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
Axes3D.plot(ax, ip1[0], ip1[1], ip1[2], 'r*', markersize=1)
Axes3D.plot(ax, ip1[0] + op1[0]*100, ip1[1] + op1[1]*100, ip1[2] + op1[2]*100, 'b.', markersize=1)

# %%
###---------------------------------###############
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout, Lambda
from keras.losses import MeanSquaredError, cosine_similarity
from keras.optimizers import SGD, Adam
from keras.utils import normalize
from livelossplot import PlotLossesKeras
import keras.backend as kb
import keras

# %%
kb.epsilon()
# Out:
# 1e-07

# %%
# normaliZed root mean square error
def nrmse_loss(ya, yp): # y actual, y predicted
    ypn = yp / (kb.epsilon() + kb.sqrt(kb.sum(kb.square(yp), keepdims=True)))
    yan = ya / (kb.epsilon() + kb.sqrt(kb.sum(kb.square(ya), keepdims=True)))
    mse = kb.sum(kb.square(ya-yp))
    return mse

# %%
# Fitting params
epochs=100

# NN creation
model = Sequential()
# model.add(BatchNormalization())
model.add(Dense(1000, input_dim=3, activation = "sigmoid"))
model.add(Dropout(0.2))
model.add(Dense(100, activation = "sigmoid"))
# model.add(Dropout(0.2))
model.add(Dense(3, activation="linear"))
model.compile(loss='mse', optimizer=SGD(lr=0.01), metrics=['mse', 'accuracy'])

# %%
# Train the network
history = model.fit(i.T, o.T, epochs=epochs, batch_size=1000, validation_split=0.2,\
                    )
# Out:
# Train on 9692 samples, validate on 2423 samples
# Epoch 1/100
# 9692/9692 [==============================] - 0s 17us/step - loss: 1021.4048 - mse: 0.3478 - accuracy: 0.2955 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3009
# Epoch 2/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2781 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2996
# Epoch 3/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2801 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 4/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 5/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2785 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 6/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2762 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3013
# Epoch 7/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2762 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2992
# Epoch 8/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2794 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2992
# Epoch 9/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2779 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 10/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2780 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 11/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2791 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 12/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2765 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 13/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2793 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2976
# Epoch 14/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2796 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3038
# Epoch 15/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2781 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 16/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2815 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 17/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2783 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 18/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2798 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3013
# Epoch 19/100
# 9692/9692 [==============================] - 0s 8us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2782 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3054
# Epoch 20/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2803 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 21/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2769 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 22/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2785 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 23/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2775 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 24/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2791 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 25/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2759 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3104
# Epoch 26/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2739 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2988
# Epoch 27/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2780 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 28/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2763 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3025
# Epoch 29/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2753 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2943
# Epoch 30/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2789 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 31/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2790 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3009
# Epoch 32/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2779 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 33/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2785 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2943
# Epoch 34/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2769 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 35/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2788 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 36/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2800 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3046
# Epoch 37/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2757 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3071
# Epoch 38/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2792 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2947
# Epoch 39/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2763 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3062
# Epoch 40/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2790 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2955
# Epoch 41/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2788 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3079
# Epoch 42/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2781 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2905
# Epoch 43/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2765 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 44/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 45/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2780 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3058
# Epoch 46/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 47/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2800 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3038
# Epoch 48/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2768 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 49/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2775 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2967
# Epoch 50/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2750 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 51/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2779 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3009
# Epoch 52/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2782 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 53/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2784 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2972
# Epoch 54/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2802 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3025
# Epoch 55/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2803 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3000
# Epoch 56/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2761 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 57/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2771 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2992
# Epoch 58/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2787 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3000
# Epoch 59/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2767 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 60/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2764 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2955
# Epoch 61/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2764 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3009
# Epoch 62/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2775 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2992
# Epoch 63/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3025
# Epoch 64/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2772 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3046
# Epoch 65/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2803 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2963
# Epoch 66/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2807 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2992
# Epoch 67/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 68/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2814 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005
# Epoch 69/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2786 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3054
# Epoch 70/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2777 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2988
# Epoch 71/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2774 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3046
# Epoch 72/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2750 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3013
# Epoch 73/100
# 9692/9692 [==============================] - 0s 6us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2772 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2996
# Epoch 74/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2781 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3066
# Epoch 75/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2780 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2967
# Epoch 76/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2806 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3013
# Epoch 77/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2783 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3021
# Epoch 78/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2779 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2988
# Epoch 79/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2793 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2963
# Epoch 80/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2817 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2955
# Epoch 81/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2797 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 82/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2787 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 83/100
# 9692/9692 [==============================] - 0s 8us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2784 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3000
# Epoch 84/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2782 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2996
# Epoch 85/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2754 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2996
# Epoch 86/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2783 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3058
# Epoch 87/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2762 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2963
# Epoch 88/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2777 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 89/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2763 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2943
# Epoch 90/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2793 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3025
# Epoch 91/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2820 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2984
# Epoch 92/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2830 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 93/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2746 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3087
# Epoch 94/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2755 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.2976
# Epoch 95/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2801 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3009
# Epoch 96/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2770 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3033
# Epoch 97/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2778 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3017
# Epoch 98/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2796 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3025
# Epoch 99/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2778 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3062
# Epoch 100/100
# 9692/9692 [==============================] - 0s 7us/step - loss: 978.0091 - mse: 0.3333 - accuracy: 0.2793 - val_loss: 899.2691 - val_mse: 0.3333 - val_accuracy: 0.3005

# %%
plt.plot(history.history['loss'], label='train', color='r')
plt.plot(history.history['val_loss'], color='orange')
plt.plot(history.history['accuracy'], color='b')

# %%
# Save the Model
model.save("field_model")

# %%
# Get subset of data to test model fit
op = model.predict(i.T)

# %%
i[:, :10].shape, o[:,:10].shape
# Out:
# ((3, 10), (3, 10))

# %%
err = op-o.T
np.var(err, axis=0), np.mean(err, axis=0)
# Out:
# (array([0.03749592, 0.03009432, 0.01751727]),
#  array([-0.00645529, -0.01363815,  0.00540987]))

# %%
#Get a crude mean and variance from training data to output
depth=len(i[0,:])
ip = i[:, 0:depth]
oc = o[:, 0:depth]
op = model.predict(ip.T).T
op = op/np.linalg.norm(op, axis=0)
diff = op - oc
np.var(diff, axis=1), np.mean(diff, axis=1), ip.shape
# Out:
# (array([0.02519149, 0.01866147, 0.02712789]),
#  array([-0.00471573, -0.01031641, -0.00702299]),
#  (3, 12115))

# %%
def set_axes_equal(ax):
    '''Make axes of 3D plot have equal scale so that spheres appear as spheres,
    cubes as cubes, etc..  This is one possible solution to Matplotlib's
    ax.set_aspect('equal') and ax.axis('equal') not working for 3D.

    Input
      ax: a matplotlib axis, e.g., as output from plt.gca().
    '''

    x_limits = ax.get_xlim3d()
    y_limits = ax.get_ylim3d()
    z_limits = ax.get_zlim3d()

    x_range = abs(x_limits[1] - x_limits[0])
    x_middle = np.mean(x_limits)
    y_range = abs(y_limits[1] - y_limits[0])
    y_middle = np.mean(y_limits)
    z_range = abs(z_limits[1] - z_limits[0])
    z_middle = np.mean(z_limits)

    # The plot bounding box is a sphere in the sense of the infinity
    # norm, hence I call half the max range the plot radius.
    plot_radius = 0.5*max([x_range, y_range, z_range])

    ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius])
    ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
    ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

# %%
#PLOT the field nodes, the training set vectors and predicted vectors
#Initialize 3d figure
length = 500
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.axis('auto')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
Axes3D.plot(ax, ip[0], ip[1], ip[2], 'g*', markersize=1)
Axes3D.plot(ax, ip[0] + oc[0]*length, \
            ip[1] + oc[1]*length, \
            ip[2] + oc[2]*length, \
            'r.', markersize=1)
Axes3D.plot(ax, ip[0] + op[0]*length, \
            ip[1] + op[1]*length, \
            ip[2] + op[2]*length, \
            'b.', markersize=1)
# Axes3D.plot(ax, diff[0], diff[1], diff[2])
set_axes_equal(ax)

# %%
# Plot outline of the field
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
Axes3D.plot(ax, i[0], i[1], i[2], 'g*', markersize=1)

# %%
xt = np.expand_dims(np.linspace(-3000, -3100, 11), axis=1).T
yt = np.expand_dims(np.linspace(-4600, -4500, 11), axis=1).T
zt = np.expand_dims(np.ones(xt[0].shape)*17, axis=1).T
ii = np.concatenate((zt,yt,zt), axis = 0)
oe = model.predict(ii.T)
oe.shape, oe

# %%
#Initialize 3d figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
Axes3D.plot(ax, diff[0], diff[1], diff[2], 'g*', markersize=3)
# Axes3D.plot(ax, ip[0] + oc[0]*100, ip[1] + oc[1]*100, ip[2] + oc[2]*100, 'r.', markersize=3)
# Axes3D.plot(ax, ip[0] + op[0]*100, ip[1] + op[1]*100, ip[2] + op[2]*100, 'b.', markersize=3)

# %%
mask = x>-3000
xt = x[mask]
yt = y[mask]
zt = z[mask]
mask2 = inrange<-2900
xt = xt[mask2]
yt = yt[mask2]
zt = zt[mask2]
xt, yt, zt

# %%
## Trying to use svd
